# %% [markdown]
# # SAUBER ML Test Notebook

# %% [markdown]
# # Import modules

# %%
import numpy as np
import pandas as pd
from os import path
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import setup_env
# Out:
# <function get_engine at 0x7f372c239510>

# %% [markdown]
# ### Establish connection to database

# %%
engine = setup_env.get_database()
print(engine)
try:
    con = engine.raw_connection()
    con.cursor().execute("SET SCHEMA '{}'".format("here_traffic"))
except:
    print("Con: DB Verbindung prüfen!") 
    exit
# Out:
# DB Engine läuft
# Engine(postgresql://postgres:***@192.168.10.184:5430/here)

# %% [markdown]
# #### SQL query structure

# %%
sql_query = f"""
     SELECT *
     FROM here_streets.streets_stuttgart
     WHERE perc_data > 75
"""

# %% [markdown]
# #### Execute SQL query

# %%
# %%time
pd_read = pd.read_sql_query(sql_query, con)
# Out:
# CPU times: user 23.4 ms, sys: 12.5 ms, total: 35.9 ms
# Wall time: 236 ms

# %% [markdown]
# #### Read into Pandas dataframe

# %%
df = pd.DataFrame(
    pd_read,
    columns=[
        "link_id",
        "dir_travel",
        "perc_data",
        "geom"
    ],
)

# %% [markdown]
# Check DF length to make sure it actually has values

# %%
if df.shape[0] == 0:
    print("Empty dataframe. Exiting")
    exit()

# %% [markdown]
# Our data contains gaps. Check their amount by searching for gaps in timestamp > 1 hour.

# %%
pick_path = "./pickles/streets_stuttgart.pkl"
if not path.exists(pick_path):
    df.to_pickle(pick_path)
else:
    df_streets = pd.read_pickle(pick_path)

# %% [markdown]
# Check that import worked

# %%
if df_streets.empty:
    print("Reading file failed or file empty")
    exit()

# %% [markdown]
# For correct SQL syntax, we turn the Link ID Dataframe column into a tuple.

# %%
rand_streets = tuple(list(df_streets["link_id"].sample(n=100).values))

# %%
rows = "*"
sel_min_confidence = 0
sel_max_weekday = 8
sel_func_classes = ('4','3')
sel_dir_travel = 'F'

# %%
sql_query = f"""
    SELECT DISTINCT tr.*  
    FROM here_traffic.stuttgart_traffic tr
    JOIN here_streets.fc_streets_all_2018q3 st on tr.link_id = st.link_id
    --LEFT JOIN public.holidays hd on date_trunc('day',tr.datum_zeit) = hd.hdate
    WHERE tr.link_id in {rand_streets}
    AND tr.confidence > {sel_min_confidence}
    AND tr.weekday_n < {sel_max_weekday}
    --AND st.func_class in {sel_func_classes}
    AND tr.dir_travel like '%{sel_dir_travel}%'
    --AND hd.hdate is null
    ORDER BY tr.datum_zeit
"""

# %%
# %%time
pd_read = pd.read_sql_query(sql_query, con)
# Out:
# CPU times: user 1.07 s, sys: 206 ms, total: 1.27 s
# Wall time: 23 s

# %%
df = pd.DataFrame(
    pd_read,
    columns=[
        "id_pk",        #0
        "link_id",      #1
        "dir_travel",
        "mean_kmh",     #2
        "min_kmh",      #3
        "max_kmh",      #4
        "datum_zeit",   #5
        "weekday_n",    #6
        "epoch_60",     #7
        "freeflow_kmh",
        "confidence",
        "count_n"
    ],
)

# %%
df.set_index('datum_zeit', inplace=True, drop=True)
df.sort_index(inplace=True)
print(df,df.index)
# Out:
#                          id_pk     link_id dir_travel  mean_kmh  min_kmh  \
# datum_zeit
# 2018-05-01 02:00:00  153723413  1193751145          F      30.9       22
# 2018-05-01 02:00:00  165104681    52854181          F      28.0       28
# 2018-05-01 03:00:00   29614136  1193644556          F      51.9       43
# 2018-05-01 03:00:00   35103438    52854068          F      35.0       35
# 2018-05-01 03:00:00  129645864   810183914          F      53.0       51
# ...                        ...         ...        ...       ...      ...
# 2019-04-30 23:00:00  158635971  1188593908          F      60.4       54
# 2019-04-30 23:00:00  165111708    52854181          F      47.2       32
# 2019-04-30 23:00:00  168567201   792262766          F      48.6       28
# 2019-04-30 23:00:00  169852827   981181256          F      53.0       48
# 2019-04-30 23:00:00  173184966  1188911119          F      50.0       40
#
#                      max_kmh  weekday_n  epoch_60 freeflow_kmh  confidence  \
# datum_zeit
# 2018-05-01 02:00:00       41          2         2         None          40
# 2018-05-01 02:00:00       28          2         2         None          10
# 2018-05-01 03:00:00       54          2         3         None          40
# 2018-05-01 03:00:00       35          2         3         None          10
# 2018-05-01 03:00:00       55          2         3         None          30
# ...                      ...        ...       ...          ...         ...
# 2019-04-30 23:00:00       63          2        23         None          40
# 2019-04-30 23:00:00       54          2        23         None          30
# 2019-04-30 23:00:00       69          2        23         None          40
# 2019-04-30 23:00:00       58          2        23         None          40
# 2019-04-30 23:00:00       57          2        23         None          30
#
#                      count_n
# datum_zeit
# 2018-05-01 02:00:00        7
# 2018-05-01 02:00:00        1
# 2018-05-01 03:00:00       12
# 2018-05-01 03:00:00        1
# 2018-05-01 03:00:00        2
# ...                      ...
# 2019-04-30 23:00:00        8
# 2019-04-30 23:00:00        4
# 2019-04-30 23:00:00        8
# 2019-04-30 23:00:00        5
# 2019-04-30 23:00:00        3
#
# [155660 rows x 11 columns] DatetimeIndex(['2018-05-01 02:00:00', '2018-05-01 02:00:00',
#                '2018-05-01 03:00:00', '2018-05-01 03:00:00',
#                '2018-05-01 03:00:00', '2018-05-01 03:00:00',
#                '2018-05-01 03:00:00', '2018-05-01 03:00:00',
#                '2018-05-01 03:00:00', '2018-05-01 03:00:00',
#                ...
#                '2019-04-30 23:00:00', '2019-04-30 23:00:00',
#                '2019-04-30 23:00:00', '2019-04-30 23:00:00',
#                '2019-04-30 23:00:00', '2019-04-30 23:00:00',
#                '2019-04-30 23:00:00', '2019-04-30 23:00:00',
#                '2019-04-30 23:00:00', '2019-04-30 23:00:00'],
#               dtype='datetime64[ns]', name='datum_zeit', length=155660, freq=None)

# %%
df
# Out:
#                          id_pk     link_id dir_travel  mean_kmh  min_kmh  \
# datum_zeit
# 2018-05-01 02:00:00  153723413  1193751145          F      30.9       22
# 2018-05-01 02:00:00  165104681    52854181          F      28.0       28
# 2018-05-01 03:00:00   29614136  1193644556          F      51.9       43
# 2018-05-01 03:00:00   35103438    52854068          F      35.0       35
# 2018-05-01 03:00:00  129645864   810183914          F      53.0       51
# ...                        ...         ...        ...       ...      ...
# 2019-04-30 23:00:00  158635971  1188593908          F      60.4       54
# 2019-04-30 23:00:00  165111708    52854181          F      47.2       32
# 2019-04-30 23:00:00  168567201   792262766          F      48.6       28
# 2019-04-30 23:00:00  169852827   981181256          F      53.0       48
# 2019-04-30 23:00:00  173184966  1188911119          F      50.0       40
#
#                      max_kmh  weekday_n  epoch_60 freeflow_kmh  confidence  \
# datum_zeit
# 2018-05-01 02:00:00       41          2         2         None          40
# 2018-05-01 02:00:00       28          2         2         None          10
# 2018-05-01 03:00:00       54          2         3         None          40
# 2018-05-01 03:00:00       35          2         3         None          10
# 2018-05-01 03:00:00       55          2         3         None          30
# ...                      ...        ...       ...          ...         ...
# 2019-04-30 23:00:00       63          2        23         None          40
# 2019-04-30 23:00:00       54          2        23         None          30
# 2019-04-30 23:00:00       69          2        23         None          40
# 2019-04-30 23:00:00       58          2        23         None          40
# 2019-04-30 23:00:00       57          2        23         None          30
#
#                      count_n
# datum_zeit
# 2018-05-01 02:00:00        7
# 2018-05-01 02:00:00        1
# 2018-05-01 03:00:00       12
# 2018-05-01 03:00:00        1
# 2018-05-01 03:00:00        2
# ...                      ...
# 2019-04-30 23:00:00        8
# 2019-04-30 23:00:00        4
# 2019-04-30 23:00:00        8
# 2019-04-30 23:00:00        5
# 2019-04-30 23:00:00        3
#
# [155660 rows x 11 columns]

# %%
plt.figure(figsize=(40,10))

# plt_all = sns.lineplot(x=df.index,y=df["count_n"], hue=df["link_id"])
plt_day = sns.lineplot(x=df.index,y=df["count_n"].rolling(24).mean(),label="24 hour rolling average", hue=df["link_id"])
#plt_wk = sns.lineplot(x=df.index,y=df["count_n"].rolling(288).mean(),label="7 day rolling average")
plt_mon = sns.lineplot(x=df.index,y=df["count_n"].rolling(720).mean(),label="1 month rolling average")
